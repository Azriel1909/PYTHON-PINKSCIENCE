# %% [markdown]
# # Reporte Análisis III
# Elaborado por Ximena Toledo

# %%
import pandas as pd

# %%
dataset = pd.read_csv('Alquiler_Residencial.csv', sep = ';')
dataset.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento     Barranco        3         1       0    70   1200.0
# 5        Departamento        Comas        2         0       0    50   1300.0
# 6  Casa en condominio          Ate        5         4       5   750  22000.0
# 7  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 8        Departamento   Pachacámac        1         0       0    36   1200.0
# 9        Departamento      Mi Perú        2         1       0    70   1500.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2          390.0      20.0
# 3          230.0       NaN
# 4            NaN       NaN
# 5          301.0      17.0
# 6            NaN       NaN
# 7            NaN       NaN
# 8            NaN       NaN
# 9          642.0      74.0

# %% [markdown]
# ## Agrupaciones

# %%
dataset['Valor'].mean() # Media
# Out:
# 5095.886100893326

# %%
barrios = ['Ate', 'Barranco', 'Comas', 'Lince', 'El Agustino', 'San Luis', 'Callao']
seleccion = dataset['Distrito'].isin(barrios)
dataset = dataset[seleccion]

# %%
dataset.head(10)
# Out:
#                   Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 3         Departamento          Ate        1         0       0    48    800.0
# 4         Departamento     Barranco        3         1       0    70   1200.0
# 5         Departamento        Comas        2         0       0    50   1300.0
# 6   Casa en condominio          Ate        5         4       5   750  22000.0
# 7   Casa en condominio  El Agustino        2         2       0    65   1000.0
# 14  Casa en condominio     San Luis        3         1       1   115   2000.0
# 15        Departamento       Callao        3         0       0    54    950.0
# 16        Departamento          Ate        2         1       1    67   1700.0
# 18  Casa en condominio          Ate        4         3       2   466   7500.0
# 21        Departamento        Comas        3         1       1   125   7000.0
#
#     Mantenimiento  Impuesto
# 3           230.0       NaN
# 4             NaN       NaN
# 5           301.0      17.0
# 6             NaN       NaN
# 7             NaN       NaN
# 14            NaN       NaN
# 15          300.0      28.0
# 16          589.0     147.0
# 18         2695.0       NaN
# 21         2100.0     463.0

# %%
dataset['Distrito'].drop_duplicates()
# Out:
# 3             Ate
# 4        Barranco
# 5           Comas
# 7     El Agustino
# 14       San Luis
# 15         Callao
# 24          Lince
# Name: Distrito, dtype: object

# %%
grupo_barrio = dataset.groupby('Distrito')

# %%
type(grupo_barrio)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_barrio.groups
# Out:
# {'Ate': [3, 6, 16, 18, 23, 32, 34, 37, 44, 45, 58, 64, 65, 66, 68, 72, 78, 83, 86, 98, 112, 115, 117, 123, 134, 137, 139, 143, 158, 161, 163, 173, 174, 182, 197, 200, 220, 227, 234, 237, 246, 249, 252, 257, 272, 278, 288, 290, 305, 306, 307, 309, 316, 322, 325, 340, 350, 351, 360, 375, 381, 383, 389, 395, 402, 404, 415, 427, 433, 448, 449, 451, 452, 455, 465, 468, 479, 480, 482, 490, 493, 502, 514, 520, 524, 532, 538, 559, 560, 561, 562, 565, 569, 574, 576, 577, 578, 609, 613, 614, ...], 'Barranco': [4, 181, 1073, 1210, 1746, 2081, 2168, 2732, 2843, 3110, 3406, 3843, 4947, 4991, 5474, 5717, 6368, 6733, 7716, 8093, 9483, 9969, 10011, 10324, 10586, 11325, 11564, 11892, 12007, 12242, 12683, 12752, 12766, 13345, 13993, 14082, 14956, 15738, 16778, 17082, 17997, 18602, 19568, 19621, 19662, 20410, 20898, 21313, 21856, 21887, 21907, 21908, 22315, 22362, 22532], 'Callao': [15, 62, 88, 111, 129, 142, 164, 171, 199, 217, 235, 285, 319, 320, 361, 398, 472, 510, 555, 631, 719, 731, 816, 850, 900, 922, 1012, 1151, 1155, 1415, 1508, 1566, 1595, 1599, 1621, 1638, 1770, 1849, 1865, 1906, 1919, 1971, 2003, 2019, 2033, 2146, 2147, 2271, 2308, 2331, 2361, 2367, 2372, 2418, 2440, 2447, 2473, 2610, 2641, 2662, 2671, 2673, 2716, 2739, 2767, 2820, 2824, 2844, 3027, 3069, 3096, 3109, 3141, 3158, 3197, 3217, 3249, 3321, 3324, 3442, 3482, 3824, 3853, 3886, 3968, 3974, 3986, 4007, 4019, 4065, 4090, 4101, 4136, 4164, 4247, 4289, 4319, 4360, 4458, 4504, ...], 'Comas': [5, 21, 41, 42, 47, 54, 55, 59, 77, 89, 97, 120, 127, 135, 149, 167, 187, 189, 229, 230, 243, 255, 258, 260, 265, 283, 297, 317, 341, 353, 356, 385, 392, 401, 407, 409, 420, 460, 499, 507, 508, 536, 544, 546, 557, 592, 600, 601, 602, 604, 615, 617, 640, 651, 655, 656, 677, 678, 686, 702, 712, 721, 739, 741, 748, 756, 760, 762, 777, 778, 784, 788, 813, 817, 828, 836, 846, 848, 853, 866, 896, 897, 914, 926, 946, 947, 964, 968, 979, 992, 994, 1013, 1029, 1031, 1040, 1048, 1057, 1069, 1074, 1080, ...], 'El Agustino': [7, 308, 590, 594, 881, 1259, 1323, 1420, 1586, 1695, 2220, 2273, 2281, 2284, 2327, 2401, 2421, 2461, 2782, 2787, 3126, 3447, 3870, 4508, 4527, 4588, 4615, 4748, 5064, 5210, 5649, 5852, 5858, 6033, 6246, 6299, 6569, 6906, 6966, 7034, 7125, 7166, 7352, 7406, 7488, 7854, 7989, 8082, 8094, 8156, 8232, 8347, 9268, 9467, 9653, 9808, 9953, 10033, 10184, 10274, 10371, 10588, 10689, 10968, 11149, 11265, 11273, 11524, 11579, 11698, 11776, 12110, 12171, 12418, 12442, 12508, 12575, 12925, 13208, 13460, 13468, 13620, 13673, 13698, 13733, 13866, 13949, 14120, 14353, 14406, 14542, 14789, 14799, 14888, 15118, 15182, 15258, 15259, 15372, 15514, ...], 'Lince': [24, 53, 76, 145, 188, 211, 266, 279, 301, 336, 347, 379, 393, 498, 523, 526, 543, 552, 564, 583, 644, 692, 708, 710, 740, 754, 755, 814, 950, 1032, 1051, 1059, 1088, 1094, 1115, 1157, 1170, 1196, 1213, 1236, 1261, 1273, 1294, 1303, 1349, 1357, 1393, 1454, 1473, 1532, 1536, 1585, 1636, 1674, 1685, 1708, 1715, 1736, 1789, 1840, 1844, 1887, 1961, 1974, 1987, 2024, 2079, 2109, 2113, 2248, 2290, 2330, 2337, 2368, 2417, 2432, 2487, 2566, 2616, 2663, 2683, 2733, 2738, 2742, 2761, 2792, 2872, 2882, 2901, 2915, 2942, 2981, 2988, 2995, 3005, 3026, 3071, 3093, 3139, 3182, ...], 'San Luis': [14, 51, 101, 124, 160, 201, 207, 224, 269, 364, 373, 447, 492, 646, 661, 785, 839, 858, 899, 943, 1020, 1091, 1235, 1262, 1313, 1365, 1501, 1539, 1554, 1578, 1713, 1756, 1757, 1768, 1787, 1833, 2023, 2089, 2098, 2150, 2166, 2212, 2240, 2242, 2268, 2300, 2343, 2446, 2491, 2561, 2608, 2690, 2961, 2963, 3134, 3190, 3277, 3329, 3382, 3431, 3441, 3490, 3506, 3638, 3657, 3670, 3679, 3716, 3759, 3803, 3808, 3851, 3861, 3924, 3952, 4000, 4002, 4036, 4135, 4286, 4355, 4383, 4467, 4497, 4499, 4532, 4644, 4814, 4896, 4966, 5040, 5073, 5091, 5114, 5123, 5174, 5245, 5302, 5335, 5386, ...]}

# %%
for barrio, data in grupo_barrio:
  print(barrio)
# Out:
# Ate
# Barranco
# Callao
# Comas
# El Agustino
# Lince
# San Luis

# %%
for barrio, data in grupo_barrio:
  print('{} -> {}'.format(barrio, data.Valor.mean ()))
# Out:
# Ate -> 6944.463922638234
# Barranco -> 1343.2727272727273
# Callao -> 4864.530612244898
# Comas -> 8816.758551307847
# El Agustino -> 1161.0143884892086
# Lince -> 1634.81210592686
# San Luis -> 1957.0977443609022

# %%
grupo_barrio['Valor'].mean()
# Out:
# Distrito
# Ate            6944.463923
# Barranco       1343.272727
# Callao         4864.530612
# Comas          8816.758551
# El Agustino    1161.014388
# Lince          1634.812106
# San Luis       1957.097744
# Name: Valor, dtype: float64

# %%
grupo_barrio['Valor'].mean().round(2)
# Out:
# Distrito
# Ate            6944.46
# Barranco       1343.27
# Callao         4864.53
# Comas          8816.76
# El Agustino    1161.01
# Lince          1634.81
# San Luis       1957.10
# Name: Valor, dtype: float64

# %%
grupo_barrio[['Valor', 'Mantenimiento']].mean().round(2)
# Out:
#                Valor  Mantenimiento
# Distrito
# Ate          6944.46        3568.04
# Barranco     1343.27         381.75
# Callao       4864.53         719.02
# Comas        8816.76        2107.92
# El Agustino  1161.01         298.87
# Lince        1634.81         528.62
# San Luis     1957.10         518.60

# %%
import pandas as pd
alumnos = pd.DataFrame({
'Nombre': ['Ary', 'Katia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
'Edad': [15, 27, 56, 32, 42, 21, 19, 35], 
'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
'Aprobado': [True, False, False, True, True, True, False, False]}, 
columns = ['Nombre', 'Edad', 'Sexo', 'Notas', 'Aprobado'])

# %%
sexo = alumnos.groupby('Sexo')
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %% [markdown]
# ## Estadísticas Descritptivas

# %%
grupo_barrio['Valor'].describe().round(2)
# Out:
#               count     mean       std    min     25%     50%      75%  \
# Distrito
# Ate          4033.0  6944.46  11722.83  100.0  2500.0  4400.0   8500.0
# Barranco       55.0  1343.27   1391.96  450.0   775.0  1100.0   1200.0
# Callao        490.0  4864.53  43732.69  500.0  1200.0  1700.0   2237.5
# Comas        1988.0  8816.76   8645.06  400.0  3800.0  6500.0  10000.0
# El Agustino   139.0  1161.01    727.50  500.0   800.0  1000.0   1200.0
# Lince         793.0  1634.81   2466.59  300.0   800.0  1120.0   1700.0
# San Luis      399.0  1957.10   2706.48  500.0  1000.0  1400.0   2000.0
#
#                   max
# Distrito
# Ate          600000.0
# Barranco       8000.0
# Callao       800000.0
# Comas        100000.0
# El Agustino    5500.0
# Lince         45000.0
# San Luis      45000.0

# %%
grupo_barrio['Valor'].aggregate(['min', 'max']).rename(columns = {'min':'Mínimo', 'max':'Máximo'})
# Out:
#              Mínimo    Máximo
# Distrito
# Ate           100.0  600000.0
# Barranco      450.0    8000.0
# Callao        500.0  800000.0
# Comas         400.0  100000.0
# El Agustino   500.0    5500.0
# Lince         300.0   45000.0
# San Luis      500.0   45000.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20,10))

# %%
fig = grupo_barrio['Valor'].mean().plot.bar(color = 'pink')
fig.set_ylabel('Valor del Alquiler')
fig.set_title('Valor Medio del alquiles por Distrito', {'fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Valor Medio del alquiles por Distrito')

# %%
fig = grupo_barrio['Valor'].max().plot.bar(color = 'pink')
fig.set_ylabel('Valor del Alquiler')
fig.set_title('Valor Máximo del alquiles por Distrito', {'fontsize': 20})
# Out:
# Text(0.5, 1.0, 'Valor Máximo del alquiles por Distrito')

# %% [markdown]
# ## Desafío

# %%
precios = pd.DataFrame([
['Feria', 'Cebolla', 2.5], 
         ['Mercado', 'Cebolla', 1.99], 
         ['Supermercado', 'Cebolla', 1.69], 
         ['Feria', 'Tomate', 4], 
         ['Mercado', 'Tomate', 3.29], 
         ['Supermercado', 'Tomate', 2.99], 
         ['Feria', 'Papa', 4.2], 
         ['Mercado', 'Papa', 3.99], 
         ['Supermercado', 'Papa', 3.69]], 
columns = ['Local', 'Producto', 'Precio'])
precios
# Out:
#           Local Producto  Precio
# 0         Feria  Cebolla    2.50
# 1       Mercado  Cebolla    1.99
# 2  Supermercado  Cebolla    1.69
# 3         Feria   Tomate    4.00
# 4       Mercado   Tomate    3.29
# 5  Supermercado   Tomate    2.99
# 6         Feria     Papa    4.20
# 7       Mercado     Papa    3.99
# 8  Supermercado     Papa    3.69

# %%
productos = precios.groupby('Producto')
productos.describe().round(2)
# Out:
#          Precio
#           count  mean   std   min   25%   50%   75%  max
# Producto
# Cebolla     3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Papa        3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2
# Tomate      3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0

# %%
estadisticas = ['mean', 'std', 'min', 'max']
nombres = {'mean': 'Promedio', 'std': 'Desviación Estándar','min': 'Mínimo', 'max': 'Máximo'}
productos['Precio'].aggregate(estadisticas).rename(columns = nombres).round(2)
# Out:
#           Promedio  Desviación Estándar  Mínimo  Máximo
# Producto
# Cebolla       2.06                 0.41    1.69     2.5
# Papa          3.96                 0.26    3.69     4.2
# Tomate        3.43                 0.52    2.99     4.0

# %% [markdown]
# ## Creando Rangos de Valor

# %%
dataset = pd.read_csv('alquiler.csv', sep = ';')
dataset.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2     Local comercial          Ate        0         4       0   150   5200.0
# 3        Departamento   Pachacámac        1         0       0    15    800.0
# 4        Departamento          Ate        1         0       0    48    800.0
# 5        Departamento     Barranco        3         1       0    70   1200.0
# 6        Departamento        Comas        2         0       0    50   1300.0
# 7  Casa en condominio          Ate        5         4       5   750  22000.0
# 8  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 9     Local comercial   Pachacámac        0         3       0   695  35000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# 4          230.0       NaN
# 5            NaN       NaN
# 6          301.0      17.0
# 7            NaN       NaN
# 8            NaN       NaN
# 9        19193.0    3030.0

# %%
# 1 y 2 cuartos
# 3 y 4 cuartos
# 5 y 6 cuartos
# 7 o + cuartos

# %%
clases = [0,2, 4, 6, 100] # Cortes

# %%
cuartos = pd.cut(dataset.Cuartos, clases)
cuartos
# Out:
# 0        (0.0, 2.0]
# 1        (0.0, 2.0]
# 2               NaN
# 3        (0.0, 2.0]
# 4        (0.0, 2.0]
#             ...
# 32955           NaN
# 32956    (2.0, 4.0]
# 32957    (0.0, 2.0]
# 32958    (0.0, 2.0]
# 32959           NaN
# Name: Cuartos, Length: 32960, dtype: category
# Categories (4, interval[int64, right]): [(0, 2] < (2, 4] < (4, 6] < (6, 100]]

# %%
pd.value_counts(cuartos)
# Out:
# (0, 2]      12419
# (2, 4]       9894
# (4, 6]        709
# (6, 100]       87
# Name: Cuartos, dtype: int64

# %%
label = ['1 y 2 cuartos', '3 y 4 cuartos', '5 y 6 cuartos',' 7 cuartos ó más']

# %%
cuartos = pd.cut(dataset.Cuartos, clases, labels = label)

# %%
pd.value_counts(cuartos)
# Out:
# 1 y 2 cuartos       12419
# 3 y 4 cuartos        9894
# 5 y 6 cuartos         709
#  7 cuartos ó más       87
# Name: Cuartos, dtype: int64

# %%
cuartos = pd.cut(dataset.Cuartos, clases, labels = label, include_lowest = True)

# %%
pd.value_counts(cuartos)
# Out:
# 1 y 2 cuartos       22270
# 3 y 4 cuartos        9894
# 5 y 6 cuartos         709
#  7 cuartos ó más       87
# Name: Cuartos, dtype: int64
